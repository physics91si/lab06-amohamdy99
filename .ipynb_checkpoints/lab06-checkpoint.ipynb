# %%
# from __future__ import print_function, division

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import scipy.optimize as opt

# %% [markdown]
# # Part 1

# %%
# TODO define gaussian function here
x_axis = np.arange(-5, 5, 0.001)
def gaussian(x, amp, cen, wid):
    return amp * np.exp(-(x-cen)**2 / wid)

# %%
# TODO plot gaussians here
y1=gaussian(x_axis, 3, 1.2, 1)
y2=gaussian(x_axis, 1.5, -2.5, 3)
y3=gaussian(x_axis, 2.3, 2.3, 0.5)
plt.plot(x_axis,y1)
plt.plot(x_axis,y2)
plt.plot(x_axis,y3)
len(y1)
# Out:
# 10000

# %%
# TODO fit gaussians, with known parameters, here
best_vals, covar=opt.curve_fit(gaussian, x_axis, y1)
# TODO plot result
fit_data=gaussian(x_axis, best_vals[0],best_vals[1],best_vals[2])
plt.plot(x_axis, y1)
plt.plot(x_axis, fit_data,'--')

# %%
# TODO: load data here
hd_alpha_data=np.loadtxt(open("HDalpha_data"))
hd_alpha_data
# Out:
# array([[ 1.313590e+04, -3.570000e-08],
#        [ 1.313580e+04, -7.600000e-09],
#        [ 1.313570e+04, -7.390000e-08],
#        [ 1.313560e+04, -3.060000e-08],
#        [ 1.313550e+04, -7.140000e-08],
#        [ 1.313540e+04, -9.430000e-08],
#        [ 1.313530e+04, -6.880000e-08],
#        [ 1.313520e+04, -2.290000e-08],
#        [ 1.313510e+04, -4.330000e-08],
#        [ 1.313500e+04, -2.290000e-08],
#        [ 1.313490e+04, -7.600000e-09],
#        [ 1.313480e+04, -1.198000e-07],
#        [ 1.313470e+04, -4.840000e-08],
#        [ 1.313460e+04, -7.390000e-08],
#        [ 1.313450e+04, -2.800000e-08],
#        [ 1.313440e+04, -1.147000e-07],
#        [ 1.313430e+04, -8.410000e-08],
#        [ 1.313420e+04, -9.430000e-08],
#        [ 1.313410e+04, -1.147000e-07],
#        [ 1.313400e+04, -1.453000e-07],
#        [ 1.313390e+04, -1.606000e-07],
#        [ 1.313380e+04, -2.472000e-07],
#        [ 1.313370e+04, -2.472000e-07],
#        [ 1.313360e+04, -3.542000e-07],
# ...

# %%
# TODO: plot it
x_values=hd_alpha_data[:,0]
y_values=hd_alpha_data[:,1]
plt.plot(x_values,y_values)

# %%
# TODO: plot data as emission signal
# Not sure what that is...

# %%
# TODO: fit a function to this data and plot it
#Idk what went wrong here...
def double_gaussian(x, amp, cen, wid, amp2, cen2, wid2):
    return (amp * np.exp(-(x-cen)**2 / wid))+(amp2 * np.exp(-(x-cen2)**2 / wid2))

best_vals2, covar2=opt.curve_fit(double_gaussian, x_values, y_values)
print(best_vals2)
plt.plot(x_values,y_values)
plt.plot(x_values,double_gaussian(x_values, best_vals2[0], best_vals2[1], best_vals2[2], best_vals2[3], best_vals2[4], best_vals2[5]))
# Out:
# [1. 1. 1. 1. 1. 1.]
# C:\Users\amoha\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %% [markdown]
# # Part 2

# %%
# TODO: part 2
random_data = np.random.uniform(0,1,100)
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True, sharey=True)
ax1.plot(random_data[0:24], alpha=0.2)
ax1.tick_params(bottom="off", left="off")
ax1.set_title('First Figure')
ax2.plot(random_data[25:49], 'r', alpha=0.5)
ax2.tick_params(bottom="off", left="off")
ax2.set_title('Second Random Figure')
ax3.plot(random_data[50:74], 'g')
ax3.tick_params(bottom="off", left="off")
ax3.set_title('Yet another Random Figure')
ax4.plot(random_data[75:99], 'k', alpha=0.7)
ax4.tick_params(bottom="off", left="off")
ax4.set_xlabel('\"I\'m starting to get the hang of this\" Figure')
fig.suptitle("BIG Figure")
fig.savefig("foo.pdf", bbox_inches='tight')
# Out:
# C:\Users\amoha\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %% [markdown]
# # Part 3

# %%
def flux_for_dipole(x_pos, y_pos, Q_vals, X, Y):
    """
    Returns the flux based on the information of the charges
    and the grid of the plot.
    Code modified from Physics 113, written by Blas Cabrera
    """
    flux = np.zeros((len(X), len(Y)))
    x_m = np.outer(np.ones((X.size)), X); 
    y_m = np.outer(Y, np.ones((Y.size))); 
    for n in range(len(Q_vals)):
        flux += 2*np.pi*Q_vals[n]*(1 - (x_pos[n]-x_m)/np.sqrt((y_pos[n]-y_m)**2+(x_pos[n]-x_m)**2))
    return flux

# %%
# TODO create arrays of information
x_pos=[2, -2]
y_pos=[6, 6]
Q_vals=[1,-1]
X=np.arange(-31.5,31.5,1)
Y=np.arange(-31.5,31.5,1)
# TODO get flux
flux=flux_for_dipole(x_pos, y_pos, Q_vals,X,Y)
# TODO plot contours of the flux
plt.contour(X,Y,flux,21)

# %%
# Out:
# 63
